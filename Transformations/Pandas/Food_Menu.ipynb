# %%
from google.colab import drive

# %%
drive.mount('_content_drive')
# Out:
# Mounted at _content_drive

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/_content_drive/MyDrive/Starbucks /Starbucks/starbucks-menu-nutrition-food.csv')

# %%
data.head()
# Out:
#           Menu_Item  Calories  Fat (g)  Carb. (g)  Fiber (g)  Protein (g)
# 0      Chonga Bagel       300      5.0         50          3           12
# 1      8-Grain Roll       380      6.0         70          7           10
# 2  Almond Croissant       410     22.0         45          3           10
# 3     Apple Fritter       460     23.0         56          2            7
# 4  Banana Nut Bread       420     22.0         52          2            6

# %%
data = data.assign(Food_ID=['F' + str(i) for i in range(1, len(data) + 1)])

# %%
data.insert(0, 'Food_ID', data.pop('Food_ID'))

# %%
data.head()
# Out:
#   Food_ID         Menu_Item  Calories  Fat (g)  Carb. (g)  Fiber (g)  \
# 0      F1      Chonga Bagel       300      5.0         50          3
# 1      F2      8-Grain Roll       380      6.0         70          7
# 2      F3  Almond Croissant       410     22.0         45          3
# 3      F4     Apple Fritter       460     23.0         56          2
# 4      F5  Banana Nut Bread       420     22.0         52          2
#
#    Protein (g)
# 0           12
# 1           10
# 2           10
# 3            7
# 4            6

# %%
data.to_json('Food_Menu.json', orient='records', lines=True)
