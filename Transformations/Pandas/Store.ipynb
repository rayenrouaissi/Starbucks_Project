# %%
from google.colab import drive

# %%
drive.mount('_content_drive')
# Out:
# Mounted at _content_drive

# %%
import pandas as pd

# %%
data=pd.read_json('/content/_content_drive/MyDrive/Starbucks /Starbucks/locations.json')

# %%
data.head()
# Out:
#           city                      name country  longitude   latitude  \
# 0     Brooklyn   Target Brooklyn College      US -73.947243  40.631264
# 1  Kew Gardens        118-24 Queens Blvd      US -73.831879  40.714371
# 2     New York           88th & Broadway      US -73.975327  40.789288
# 3     New York                42nd & 2nd      US -73.972801  40.749783
# 4     New York  NHL store @ 47th & Sixth      US -73.982452  40.757786
#
#    storeId                                         storeHours
# 0     6551  {'sunday': '8:00 AM to 9:00 PM', 'monday': '8:...
# 1     6348  {'sunday': '6:00 AM to 8:00 PM', 'monday': '5:...
# 2     6590  {'sunday': '6:30 AM to 6:30 PM', 'monday': '5:...
# 3     6869                                                NaN
# 4     6945                                                NaN

# %%
data.drop(['longitude', 'latitude'], axis=1, inplace=True)

# %%
data=data[['storeId','name','city','country','storeHours']]

# %%
data.head()
# Out:
#    storeId                      name         city country  \
# 0     6551   Target Brooklyn College     Brooklyn      US
# 1     6348        118-24 Queens Blvd  Kew Gardens      US
# 2     6590           88th & Broadway     New York      US
# 3     6869                42nd & 2nd     New York      US
# 4     6945  NHL store @ 47th & Sixth     New York      US
#
#                                           storeHours
# 0  {'sunday': '8:00 AM to 9:00 PM', 'monday': '8:...
# 1  {'sunday': '6:00 AM to 8:00 PM', 'monday': '5:...
# 2  {'sunday': '6:30 AM to 6:30 PM', 'monday': '5:...
# 3                                                NaN
# 4                                                NaN

# %%
for index, row in data.iterrows():data.at[index, 'storeId'] = 'S' + str(1000 + index)

# %%
data.head()
# Out:
#   storeId                      name         city country  \
# 0   S1000   Target Brooklyn College     Brooklyn      US
# 1   S1001        118-24 Queens Blvd  Kew Gardens      US
# 2   S1002           88th & Broadway     New York      US
# 3   S1003                42nd & 2nd     New York      US
# 4   S1004  NHL store @ 47th & Sixth     New York      US
#
#                                           storeHours
# 0  {'sunday': '8:00 AM to 9:00 PM', 'monday': '8:...
# 1  {'sunday': '6:00 AM to 8:00 PM', 'monday': '5:...
# 2  {'sunday': '6:30 AM to 6:30 PM', 'monday': '5:...
# 3                                                NaN
# 4                                                NaN

# %%
data.drop(['storeHours'], axis=1, inplace=True)

# %%
data.head()
# Out:
#   storeId                      name         city country
# 0   S1000   Target Brooklyn College     Brooklyn      US
# 1   S1001        118-24 Queens Blvd  Kew Gardens      US
# 2   S1002           88th & Broadway     New York      US
# 3   S1003                42nd & 2nd     New York      US
# 4   S1004  NHL store @ 47th & Sixth     New York      US

# %%
data.to_json('Store.json', orient='records', lines=True)
